# %%
from GSVA import gsva

# %%
import pandas as pd

expression = pd.read_csv("/home/shikhar/Downloads/sub.csv")
gene_set = pd.read_csv("/home/shikhar/Downloads/genset.csv")

# %%
expression
# Out:
#        rid  aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# 0    IFIT1                       9.5                      10.5
# 1    IFI44                       9.4                      11.1
# 2    IFIT3                      10.0                      10.8
# 3      MX2                       9.8                      10.7
# 4     OAS1                      11.7                      11.0
# 5     OAS3                      11.3                      11.9
# 6     BST2                      12.2                      12.7
# 7   IFITM1                      11.2                      12.9
# 8      MX1                      11.5                      12.4
# 9    STAT1                      12.2                      12.7
# 10   IFI27                      13.5                      13.8
# 11  CXCL10                       9.4                       8.7
# 12   IFI16                      11.0                      11.3
# 13   IFI30                      11.7                      12.3
# ...

# %%
gene_set
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      GENE1         NaN      IFIT1      IFI44      IFIT3        MX2
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 18 Unnamed: 19  \
# 0       OAS1       OAS1       OAS3       BST2  ...       IFIT2      IFITM2
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0        IRF1        IRF9        IRGM       ISG15        OAS2       PSME1
#
#   Unnamed: 26 Unnamed: 27
# 0       SOCS1       STAT2
#
# [1 rows x 28 columns]

# %% [markdown]
# Applying GSVA throws a key error:'member' directed to the API.

# %%
output = gsva(expression,gene_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'member'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b68ee0140fbd> in <module>
# ----> 1 output = gsva(expression,gene_set)
#
# ...

# %% [markdown]
# Plotted a PCA graph to find out the similarity between the genes from the expression dataset

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline
pca = PCA(n_components=2)
expression = expression.dropna()
expression = expression.select_dtypes(include=['float64']).copy()
principalComponents1 = pca.fit_transform(expression)

# %%
plt.scatter(principalComponents1[:,0],principalComponents1[:,1])
